# %%
spark.sql("USE CATALOG e_comm")
spark.sql("USE SCHEMA silver")

# %%
spark.sql("create table if not exists silver.order_items(order_id string, order_item_id int, product_id string, seller_id string, shipping_limit_date timestamp, price float, freight_value float) ")

# %%
# %sql
select * from silver.order_items
