# %%
spark.sql("use catalog e_comm")

# %%
# %sql
create database if not exists silver

# %%
spark.sql("use database silver")

# %%
spark.sql("create table if not exists silver.customers(customer_id string, customer_unique_id string, customer_zip_code_prefix string, customer_city string, customer_state string, start_date timestamp, end_date timestamp, is_active boolean) using delta ")

# %%
# %sql
select * from silver.customers
