# %%
spark.sql("USE CATALOG e_comm")
spark.sql("USE SCHEMA bronze")

# %%
spark.sql("create table if not exists bronze.products(product_id string,product_category_name string, product_name_lenght double,product_description_lenght double, product_photos_qty double ,product_weight_g double,product_length_cm double, product_height_cm double, product_width_cm double, merge_flag boolean, engestion_ts timestamp) using delta ")
