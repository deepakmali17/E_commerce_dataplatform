# %%
spark.sql("USE CATALOG e_comm")
spark.sql("USE SCHEMA bronze")

# %%
spark.sql("create table if not exists bronze.sellers(seller_id string, seller_zip_code_prefix string, seller_city string, seller_state string, merge_flag boolean, ingestion_ts timestamp) using delta")
