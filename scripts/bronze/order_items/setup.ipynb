# %%
spark.sql("USE CATALOG e_comm")
spark.sql("USE SCHEMA bronze")

# %%
spark.sql("create table if not exists bronze.order_items(order_id string, order_item_id bigint, product_id string, seller_id string, shipping_limit_date string, price double, freight_value double, merge_flag boolean, ingestion_ts timestamp) using delta ")

# %%
# %sql
drop table bronze.order_items

# %%
# %sql
select * from bronze.order_items
